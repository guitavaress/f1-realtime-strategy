# %% [markdown]
# # Monte Carlo Validation
#
# Calibrate the simulator against completed 2024 races:
#
# - Run simulate() for known race + known strategy
# - Compare p50 race time vs actual race time
# - Check that actual result falls within [p10, p90] interval in most races

# %%
# Placeholder — implement after Fase 1 (predict) is complete
print('Run after realtime.simulate.montecarlo is implemented')
