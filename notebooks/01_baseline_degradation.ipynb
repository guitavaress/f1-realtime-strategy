# %% [markdown]
# # Baseline Degradation
#
# Validate that `marts.tyre_weather_profile` has enough coverage to power the predictor.
#
# - Check compound × circuit × temp_bucket coverage
# - Spot-check deg_per_lap_s distributions
# - Identify circuits with sparse data (fallback candidates)

# %%
import sys
sys.path.insert(0, '..')

from realtime.db import read_df
import pandas as pd

df = read_df('SELECT * FROM marts.tyre_weather_profile ORDER BY circuit_key, compound')
df.head()
